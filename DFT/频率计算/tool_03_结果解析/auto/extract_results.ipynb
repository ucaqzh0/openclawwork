# %% [markdown]
# # 结果解析（已拆分）
#
# **频率流程** 使用：
# - **extract_freq_loop.ipynb**：循环执行，仅提取频率、打印 PASS/HAS_IMAG/INCOMPLETE
# - **extract_final_structures.ipynb**：最终结构提取，含 507 修正结构的单独输出
#
# **GO absorption 流程** 完整版备份：`extract_results_GO_backup.ipynb`
