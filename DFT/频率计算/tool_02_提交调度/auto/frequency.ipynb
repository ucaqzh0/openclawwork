# %% [markdown]
# # 频率计算（已拆分）
#
# 本功能已拆分为：
# - **tool_01 结构准备**：`../tool_01_结构准备/auto/prepare_structure.ipynb`
#   - 结构转移、原子固定、INCAR/KPOINTS/POTCAR 生成
# - **tool_02 提交调度**：`submit_dispatch.ipynb`（本目录）
#   - 生成提交文件、核数配给、Hub 分区、灵活排任务
#
# **完整版备份**：`frequency_FULL_backup.ipynb`
