# %% [markdown]
# # tool_03 结果收尾（GO_WRAPUP）
#
# ## 功能
# - 完成态扫描（COMPLETED/FAILED/RUNNING）
# - 结果提取与表格化
# - 最低能结构筛选（GO_best）
# - 复用最小包、检查包导出
#
# ## 独立执行
# 结果提取逻辑见 `频率计算/tool_03_结果解析/auto/extract_results_GO_backup.ipynb`

# %%
import sys
from pathlib import Path
_p = Path.cwd()
while _p != _p.parent:
    if (_p / "shared" / "config.py").exists():
        sys.path.insert(0, str(_p))
        break
    _p = _p.parent
from shared.load_config import load_config
cfg = load_config()
go_root = cfg.GO_ROOT

# %%
print(f"GO_ROOT: {go_root}")
print("\n收尾流程：")
print("1. 扫描 absorption/ 下 job 完成态")
print("2. 调用 extract_results 逻辑提取能量")
print("3. 生成 GO_best（最低能结构）")
print("4. 输出复用最小包、check 包")
print("\n完整实现见 extract_results_GO_backup.ipynb")
