# %% [markdown]
# # precursor_generation 单吸附构建（检查版）
# 反应：CO+OH->COOH（C位吸附），CO+H->CHO

# %%
adsorption_distance = 2.5
print('adsorption_distance =', adsorption_distance, 'Angstrom')
print('new build: CO/COOH/CHO on hollow/top/bridge')
print('reused: H/OH via CONTCAR+OUTCAR+OSZICAR')
